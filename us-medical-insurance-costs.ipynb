# %% [markdown]
# # U.S. Medical Insurance Costs

# %%
import pandas as pd
df= pd.read_csv("insurance.csv")
print(data)
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
df['smoker'].value_counts()
# Out:
# no     1064
# yes     274
# Name: smoker, dtype: int64

# %%
df['region'].value_counts()
# Out:
# southeast    364
# southwest    325
# northwest    325
# northeast    324
# Name: region, dtype: int64

# %%
df['sex'].value_counts()
# Out:
# male      676
# female    662
# Name: sex, dtype: int64

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.figure(figsize=(9,6))
df['age'].hist()
plt.ylabel('Frequencia')
plt.xlabel('Idade')
plt.title('Distribuição de idade')
# Out:
# Text(0.5, 1.0, 'Distribuição de idade')

# %%
plt.scatter('age','charges', data=df)
plt.ylabel('Valor')
plt.xlabel('Idade')
plt.title('Valor por idade')
# Out:
# Text(0.5, 1.0, 'Valor por idade')

# %%
df.groupby(['smoker'])['charges'].agg(['mean']).plot.bar()
plt.ylabel('Valor')
plt.xlabel('Fumante')
plt.title('Valor Comparação Fumante')
# Out:
# Text(0.5, 1.0, 'Valor Comparação Fumante')

# %%
plt.scatter('bmi','charges',data = df)
plt.title('Valor por gordura corporal')
plt.xlabel('% de Gordura')
plt.ylabel('Valor')
# Out:
# Text(0, 0.5, 'Valor')
